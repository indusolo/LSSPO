# %% [markdown]
# #### Kaggle GMSC

# %%
# Necessary imports
import pandas as pd
import numpy as np
from numpy import genfromtxt
import csv
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
import matplotlib.colors
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from tensorflow.keras.models import load_model
from io import StringIO
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
import time
import random
from sklearn.model_selection import train_test_split 
from numpy.random import seed
seed(2)
import tensorflow as tf
tf.random.set_seed(7)
import random
random.seed(1)
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Lambda, Input, Dense, Layer
from tensorflow.keras.layers import BatchNormalization,LayerNormalization
from tensorflow.keras.losses import mse, binary_crossentropy,categorical_crossentropy,sparse_categorical_crossentropy
from tensorflow.keras.layers import Activation, Dense, Flatten 
from tensorflow.keras import backend as K
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import classification_report
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
import scipy
from scipy.stats import multivariate_normal
# Out:
# C:\Users\91948\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
Data_Train = pd.read_csv('cs-training.csv')
#Data_Test = pd.read_csv('../input/give-me-some-credit-dataset/cs-test.csv')

# %%
Data_Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Unnamed: 0                            150000 non-null  int64
#  1   SeriousDlqin2yrs                      150000 non-null  int64
#  2   RevolvingUtilizationOfUnsecuredLines  150000 non-null  float64
#  3   age                                   150000 non-null  int64
#  4   NumberOfTime30-59DaysPastDueNotWorse  150000 non-null  int64
#  5   DebtRatio                             150000 non-null  float64
#  6   MonthlyIncome                         120269 non-null  float64
#  7   NumberOfOpenCreditLinesAndLoans       150000 non-null  int64
#  8   NumberOfTimes90DaysLate               150000 non-null  int64
#  9   NumberRealEstateLoansOrLines          150000 non-null  int64
#  10  NumberOfTime60-89DaysPastDueNotWorse  150000 non-null  int64
#  11  NumberOfDependents                    146076 non-null  float64
# dtypes: float64(4), int64(8)
# memory usage: 13.7 MB

# %%
Train_data = Data_Train.copy()

# %%
trainID = Train_data['Unnamed: 0']
Train_data.drop(['Unnamed: 0'],axis=1, inplace=True)

# %%
y = Train_data['SeriousDlqin2yrs']
Train_data.drop(['SeriousDlqin2yrs'],axis=1,inplace=True)

# %%
Train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 10 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   RevolvingUtilizationOfUnsecuredLines  150000 non-null  float64
#  1   age                                   150000 non-null  int64
#  2   NumberOfTime30-59DaysPastDueNotWorse  150000 non-null  int64
#  3   DebtRatio                             150000 non-null  float64
#  4   MonthlyIncome                         120269 non-null  float64
#  5   NumberOfOpenCreditLinesAndLoans       150000 non-null  int64
#  6   NumberOfTimes90DaysLate               150000 non-null  int64
#  7   NumberRealEstateLoansOrLines          150000 non-null  int64
#  8   NumberOfTime60-89DaysPastDueNotWorse  150000 non-null  int64
#  9   NumberOfDependents                    146076 non-null  float64
# dtypes: float64(4), int64(6)
# memory usage: 11.4 MB

# %%
print(Train_data.isnull().sum())
# Out:
# RevolvingUtilizationOfUnsecuredLines        0
# age                                         0
# NumberOfTime30-59DaysPastDueNotWorse        0
# DebtRatio                                   0
# MonthlyIncome                           29731
# NumberOfOpenCreditLinesAndLoans             0
# NumberOfTimes90DaysLate                     0
# NumberRealEstateLoansOrLines                0
# NumberOfTime60-89DaysPastDueNotWorse        0
# NumberOfDependents                       3924
# dtype: int64

# %% [markdown]
# #### Fill the missing values with mean and mode

# %%
Train_data['MonthlyIncome'].fillna(Train_data['MonthlyIncome'].median(),inplace=True)

Train_data['NumberOfDependents'].fillna(Train_data['NumberOfDependents'].mode()[0], inplace=True)

# %%
Train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 10 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   RevolvingUtilizationOfUnsecuredLines  150000 non-null  float64
#  1   age                                   150000 non-null  int64
#  2   NumberOfTime30-59DaysPastDueNotWorse  150000 non-null  int64
#  3   DebtRatio                             150000 non-null  float64
#  4   MonthlyIncome                         150000 non-null  float64
#  5   NumberOfOpenCreditLinesAndLoans       150000 non-null  int64
#  6   NumberOfTimes90DaysLate               150000 non-null  int64
#  7   NumberRealEstateLoansOrLines          150000 non-null  int64
#  8   NumberOfTime60-89DaysPastDueNotWorse  150000 non-null  int64
#  9   NumberOfDependents                    150000 non-null  float64
# dtypes: float64(4), int64(6)
# memory usage: 11.4 MB

# %%
feat_outliers = ['DebtRatio','RevolvingUtilizationOfUnsecuredLines','NumberOfTime30-59DaysPastDueNotWorse',
                'MonthlyIncome','NumberRealEstateLoansOrLines','NumberOfDependents']

for i in range(len(feat_outliers)):
    col = feat_outliers[i]
    print(feat_outliers[i])
    
    Q3 = Train_data[col].quantile(0.75) #np.quantile(Train_data[col], 0.75)
    Q1 = Train_data[col].quantile(0.25) #np.quantile(Train_data[col], 0.25)
    IQR = Q3 - Q1

    lower_range = Q1 - 2.0 * IQR
    upper_range = Q3 + 2.0 * IQR
    print(lower_range,upper_range)
    outlier_free_list = [x for x in Train_data[col] if (
            (x > lower_range) & (x < upper_range))]
    Train_data.loc[~Train_data[col].isin(outlier_free_list)] = Train_data[col].quantile(0.5)

#Train_data["DebtRatio"],IQR
# Out:
# DebtRatio
# -1.2112860497499998 2.25461365525
# RevolvingUtilizationOfUnsecuredLines
# -0.7260611465000001 1.2249457647500002
# NumberOfTime30-59DaysPastDueNotWorse
# -0.733015682 1.099523523
# MonthlyIncome
# -14166.900476477 21251.266984317997
# NumberRealEstateLoansOrLines
# -2.0 3.0
# NumberOfDependents
# -2.0 3.0

# %%
#Normalize the data between +1 and -1

mmscaler    = MinMaxScaler(feature_range=(-1,1))
Train_data   = mmscaler.fit_transform(Train_data)

# %%
Train_data.shape
# Out:
# (150000, 10)

# %% [markdown]
# ### VAE

# %% [markdown]
# #### VAE code is adopted and modified from the following reference.
# #### https://github.com/PacktPublishing/Advanced-Deep-Learning-with-Keras/blob/master/chapter8-vae/vae-mlp-mnist-8.1.1.py

# %%
start_dimension = Train_data.shape[1]
# network parameters
input_shape = (start_dimension, )
intermediate_dim = 6
batch_size = 250
latent_dim = 3
epochs = 300

# %%
def sampling(args):
    z_mean, z_log_var = args
    # K is the keras backend
    batch = K.shape(z_mean)[0]
    dim = K.int_shape(z_mean)[1]
    # by default, random_normal has mean=0 and std=1.0
    epsilon = K.random_normal(shape=(batch, dim))
    return z_mean + K.exp(0.5 * z_log_var) * epsilon

# %%
# Encoder model
inputs = keras.Input(shape=input_shape, name='encoder_input')
x = layers.Dense(intermediate_dim, activation='tanh')(inputs)
z_mean = layers.Dense(latent_dim, name='z_mean')(x)
z_log_var = layers.Dense(latent_dim, name='z_log_var')(x)
z = Lambda(sampling,
           output_shape=(latent_dim,), 
           name='z')([z_mean, z_log_var])

encoder = keras.Model(inputs, [z_mean, z_log_var, z], name='encoder')
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 10)]         0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 6)            66          encoder_input[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 3)            21          dense[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 3)            21          dense[0][0]
# __________________________________________________________________________________________________
# z (Lambda)                      (None, 3)            0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 108
# Trainable params: 108
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Decoder model
latent_inputs = keras.Input(shape=(latent_dim,), name='z_sampling')
x = layers.Dense(intermediate_dim, activation='tanh')(latent_inputs)
outputs = layers.Dense(start_dimension, activation='tanh')(x)
decoder = keras.Model(latent_inputs, outputs, name='decoder')
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# z_sampling (InputLayer)      [(None, 3)]               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 24
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                70
# =================================================================
# Total params: 94
# Trainable params: 94
# Non-trainable params: 0
# _________________________________________________________________

# %%
# VAE model
outputs = decoder(encoder(inputs)[2])
vae = keras.Model(inputs, outputs, name='vae_mlp')

# %% [markdown]
# #### Train-Test split for classifier

# %%
X_data, X_test, y_data, y_test = train_test_split(Train_data, y, 
                                                    test_size=0.3, random_state=22,stratify=y)

# %% [markdown]
# #### Train-Validation split for VAE

# %%
X_imtrain, X_imval, y_imtrain, y_imval = train_test_split(X_data, X_data, 
                                                    test_size=0.2, random_state=1)

# %%
start_time = time.time()

# %%
if __name__ == '__main__':
    
    loss = 'mse'
    models = (encoder, decoder)
    
    if loss == 'bce':
        reconstruction_loss = binary_crossentropy(inputs,
                                                  outputs)
    else:
        reconstruction_loss = mse(inputs, outputs)
        
    reconstruction_loss *= start_dimension
    kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
    kl_loss = K.sum(kl_loss, axis=-1)
    kl_loss *= -0.5
    vae_loss = K.mean(reconstruction_loss + kl_loss)
    vae.add_loss(vae_loss)
    opt = keras.optimizers.Adam(lr =0.0001)
    vae.compile(optimizer=opt,)
    vae.summary()
            
    vae.fit(X_imtrain,
            epochs=epochs,
            #verbose = 10,
            batch_size=batch_size,
            validation_data=(X_imval, None))
# Out:
# C:\Users\91948\Anaconda3\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Model: "vae_mlp"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 10)]         0
# __________________________________________________________________________________________________
# encoder (Functional)            [(None, 3), (None, 3 108         encoder_input[0][0]
# __________________________________________________________________________________________________
# decoder (Functional)            (None, 10)           94          encoder[0][2]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 6)            66          encoder_input[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 3)            21          dense[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 3)            21          dense[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 3)            0           z_log_var[0][0]
# __________________________________________________________________________________________________
# tf.math.square (TFOpLambda)     (None, 3)            0           z_mean[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor (TFOpLambd (None, 10)           0           decoder[0][0]
# __________________________________________________________________________________________________
# tf.cast (TFOpLambda)            (None, 10)           0           encoder_input[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract (TFOpLambda)   (None, 3)            0           tf.__operators__.add[0][0]
#                                                                  tf.math.square[0][0]
# __________________________________________________________________________________________________
# tf.math.exp (TFOpLambda)        (None, 3)            0           z_log_var[0][0]
# __________________________________________________________________________________________________
# tf.math.squared_difference (TFO (None, 10)           0           tf.convert_to_tensor[0][0]
#                                                                  tf.cast[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract_1 (TFOpLambda) (None, 3)            0           tf.math.subtract[0][0]
#                                                                  tf.math.exp[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean (TFOpLambda (None,)              0           tf.math.squared_difference[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum (TFOpLambda) (None,)              0           tf.math.subtract_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   (None,)              0           tf.math.reduce_mean[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_1 (TFOpLambda) (None,)              0           tf.math.reduce_sum[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None,)              0           tf.math.multiply[0][0]
#                                                                  tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_1 (TFOpLamb ()                   0           tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# add_loss (AddLoss)              ()                   0           tf.math.reduce_mean_1[0][0]
# ==================================================================================================
# Total params: 202
# Trainable params: 202
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/300
# 336/336 [==============================] - 1s 3ms/step - loss: 7.8441 - val_loss: 7.0485
# Epoch 2/300
# 336/336 [==============================] - 1s 2ms/step - loss: 6.3582 - val_loss: 5.7083
# Epoch 3/300
# 336/336 [==============================] - 0s 1ms/step - loss: 5.1818 - val_loss: 4.7325
# Epoch 4/300
# 336/336 [==============================] - 0s 1ms/step - loss: 4.3746 - val_loss: 4.0604
# Epoch 5/300
# 336/336 [==============================] - 0s 1ms/step - loss: 3.8438 - val_loss: 3.6356
# Epoch 6/300
# 336/336 [==============================] - 0s 1ms/step - loss: 3.4907 - val_loss: 3.3473
# Epoch 7/300
# 336/336 [==============================] - 0s 1ms/step - loss: 3.2322 - val_loss: 3.1332
# Epoch 8/300
# 336/336 [==============================] - 0s 1ms/step - loss: 3.0478 - val_loss: 2.9879
# Epoch 9/300
# 336/336 [==============================] - 0s 1ms/step - loss: 2.9062 - val_loss: 2.8575
# Epoch 10/300
# 336/336 [==============================] - 1s 2ms/step - loss: 2
300
# 336/336 [==============================] - 0s 940us/step - loss: 1.8031 - val_loss: 1.8109
# Epoch 54/300
# 336/336 [==============================] - 0s 923us/step - loss: 1.8011 - val_loss: 1.8072
# Epoch 55/300
# 336/336 [==============================] - 0s 922us/step - loss: 1.8006 - val_loss: 1.8106
# Epoch 56/300
# 336/336 [==============================] - 0s 923us/step - loss: 1.8016 - val_loss: 1.8084
# Epoch 57/300
# 336/336 [==============================] - 0s 923us/step - loss: 1.8009 - val_loss: 1.8058
# Epoch 58/300
# 336/336 [==============================] - 0s 958us/step - loss: 1.7992 - val_loss: 1.8101
# Epoch 59/300
# 336/336 [==============================] - 0s 940us/step - loss: 1.7992 - val_loss: 1.8059
# Epoch 60/300
# 336/336 [==============================] - 0s 940us/step - loss: 1.8007 - val_loss: 1.8039
# Epoch 61/300
# 336/336 [==============================] - 0s 939us/step - loss: 1.8008 - val_loss: 1.8110
# Epoch 62/300
# 336/336 [==============================] - 0s 914us/step - loss: 1.8029 - val_loss: 1.8031
# Epoch 63/300
# 336/336 [==============================] - 0s 949us/step - loss: 1.7972 - val_loss: 1.8045
# Epoch 64/300
# 336/336 [==============================] - 0s 948us/step - loss: 1.7994 - val_loss: 1.8095
# Epoch 65/300
# 336/336 [==============================] - 0s 932us/step - loss: 1.7977 - val_loss: 1.8068
# Epoch 66/300
# 336/336 [==============================] - 0s 923us/step - loss: 1.7988 - val_loss: 1.8024
# Epoch 67/300
# 336/336 [==============================] - 0s 921us/step - loss: 1.8008 - val_loss: 1.8123
# Epoch 68/300
# 336/336 [==============================] - 0s 914us/step - loss: 1.8012 - val_loss: 1.8006
# Epoch 69/300
# 336/336 [==============================] - 0s 914us/step - loss: 1.7988 - val_loss: 1.8050
# Epoch 70/300
# 336/336 [==============================] - 0s 940us/step - loss: 1.7998 - val_loss: 1.8020
# Epoch 71/300
# 336/336 [==============================] - 0s 940us/step - loss: 1.7964 - val_loss: 1.8050
# Epoch 72/300
# 336/336 [==============================] - 0s 916us/step - loss: 1.8012 - val_loss: 1.8105
# Epoch 73/300
# 336/336 [==============================] - 0s 932us/step - loss: 1.7976 - val_loss: 1.8110
# Epoch 74/300
# 336/336 [==============================] - 0s 947us/step - loss: 1.7997 - val_loss: 1.8097
# Epoch 75/300
# 336/336 [==============================] - 0s 914us/step - loss: 1.8006 - val_loss: 1.8074
# Epoch 76/300
# 336/336 [==============================] - 0s 914us/step - loss: 1.7999 - val_loss: 1.8038
# Epoch 77/300
# 336/336 [==============================] - 0s 914us/step - loss: 1.7996 - val_loss: 1.8067
# Epoch 78/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.8015 - val_loss: 1.8093
# Epoch 79/300
# 336/336 [==============================] - 0s 923us/step - loss: 1.7980 - val_loss: 1.8103
# Epoch 80/300
# 336/336 [==============================] - 0s 921us/step - loss: 1.8007 - val_loss: 1.8006
# Epoch 81/300
# 336/336 [==============================] - 0s 940us/step - loss: 1.8017 - val_loss: 1.8038
# Epoch 82/300
# 336/336 [==============================] - 0s 914us/step - loss: 1.8000 - val_loss: 1.8137
# Epoch 83/300
# 336/336 [==============================] - 0s 940us/step - loss: 1.8024 - val_loss: 1.8084
# Epoch 84/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7948 - val_loss: 1.8056
# Epoch 85/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7978 - val_loss: 1.8058
# Epoch 86/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.8016 - val_loss: 1.8039
# Epoch 87/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7989 - val_loss: 1.8102
# Epoch 88/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.8011 - val_loss: 1.8103
# Epoch 89/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7984 - val_loss: 1.8048
# Epoch 90/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7981 - val_loss: 1.8074
# Epoch 91/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.8001 - val_loss: 1.8033
# Epoch 92/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7981 - val_loss: 1.8044
# Epoch 93/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7990 - val_loss: 1.8038
# Epoch 94/300
# 336/336 [==============================] - 0s 985us/step - loss: 1.7976 - val_loss: 1.8033
# Epoch 95/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7977 - val_loss: 1.8063
# Epoch 96/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.8000 - val_loss: 1.8058
# Epoch 97/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7963 - val_loss: 1.8050
# Epoch 98/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.8000 - val_loss: 1.8060
# Epoch 99/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7992 - val_loss: 1.8021
# Epoch 100/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7974 - val_loss: 1.8082
# Epoch 101/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7968 - val_loss: 1.8083
# Epoch 102/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7967 - val_loss: 1.7998
# Epoch 103/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.
300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7966 - val_loss: 1.8077
# Epoch 145/300
# 336/336 [==============================] - 0s 966us/step - loss: 1.7959 - val_loss: 1.8026
# Epoch 146/300
# 336/336 [==============================] - 0s 997us/step - loss: 1.7952 - val_loss: 1.8079
# Epoch 147/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7982 - val_loss: 1.7991
# Epoch 148/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7951 - val_loss: 1.7928
# Epoch 149/300
# 336/336 [==============================] - 0s 973us/step - loss: 1.7961 - val_loss: 1.8032
# Epoch 150/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7985 - val_loss: 1.8058
# Epoch 151/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7956 - val_loss: 1.8017
# Epoch 152/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7963 - val_loss: 1.7942
# Epoch 153/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.8002 - val_loss: 1.8009
# Epoch 154/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7969 - val_loss: 1.8022
# Epoch 155/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7937 - val_loss: 1.8014
# Epoch 156/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7932 - val_loss: 1.8029
# Epoch 157/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7939 - val_loss: 1.8054
# Epoch 158/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7955 - val_loss: 1.8073
# Epoch 159/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7990 - val_loss: 1.8127
# Epoch 160/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7915 - val_loss: 1.8023
# Epoch 161/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7952 - val_loss: 1.7999
# Epoch 162/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7944 - val_loss: 1.8016
# Epoch 163/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7983 - val_loss: 1.8032
# Epoch 164/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7943 - val_loss: 1.7999
# Epoch 165/300
# 336/336 [==============================] - 1s 3ms/step - loss: 1.7966 - val_loss: 1.8063
# Epoch 166/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7978 - val_loss: 1.8006
# Epoch 167/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7950 - val_loss: 1.8042
# Epoch 168/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7946 - val_loss: 1.8007
# Epoch 169/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7951 - val_loss: 1.8043
# Epoch 170/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7914 - val_loss: 1.8022
# Epoch 171/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7958 - val_loss: 1.8042
# Epoch 172/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7939 - val_loss: 1.8072
# Epoch 173/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7953 - val_loss: 1.7998
# Epoch 174/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7920 - val_loss: 1.8059
# Epoch 175/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7919 - val_loss: 1.8107
# Epoch 176/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7983 - val_loss: 1.7982
# Epoch 177/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7996 - val_loss: 1.8011
# Epoch 178/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7937 - val_loss: 1.8025
# Epoch 179/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7952 - val_loss: 1.8034
# Epoch 180/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7982 - val_loss: 1.8059
# Epoch 181/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7979 - val_loss: 1.8083
# Epoch 182/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7962 - val_loss: 1.8001
# Epoch 183/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7958 - val_loss: 1.8038
# Epoch 184/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7979 - val_loss: 1.8023
# Epoch 185/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7952 - val_loss: 1.8053
# Epoch 186/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7939 - val_loss: 1.8009
# Epoch 187/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7976 - val_loss: 1.7988
# Epoch 188/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7950 - val_loss: 1.7930
# Epoch 189/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7946 - val_loss: 1.7997
# Epoch 190/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7950 - val_loss: 1.7960
# Epoch 191/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7946 - val_loss: 1.8014
# Epoch 192/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7900 - val_loss: 1.8013
# Epoch 193/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7974 - val_loss: 1.7981
# Epoch 194/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7930 - val_loss: 1.7969
# Epoch 195/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7961 - val_loss: 1.8025
# Epoch 196/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7950 - val_loss: 1.8033
# Epoch 197/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7941 - val_loss: 1.8002
# Epoch 198/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7942 - val_loss: 1.8004
# Epoch 199/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7918 - val_loss: 1.8036
# Epoch 200/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7956 - val_loss: 1.8042
# Epoch 201/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7936 - val_loss: 1.8015
# Epoch 202/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7949 - val_loss: 1.8093
# Epoch 203/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7953 - val_loss: 1.8016
# Epoch 204/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7933 - val_loss: 1.8038
# Epoch 205/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7947 - val_loss: 1.7995
# Epoch 206/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7966 - val_loss: 1.7974
# Epoch 207/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7975 - val_loss: 1.8026
# Epoch 208/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7972 - val_loss: 1.8027
# Epoch 209/300
# 336/336 [==============================] - 1s 3ms/step - loss: 1.7912 - val_loss: 1.8082
# Epoch 210/300
# 336/336 [==============================] - 1s 3ms/step - loss: 1.7928 - val_loss: 1.7992
# Epoch 211/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7948 - val_loss: 1.8065
# Epoch 212/300
# 336/336 [==============================] - 1s 3ms/step - loss: 1.7961 - val_loss: 1.8063
# Epoch 213/300
# 336/336 [==============================] - 1s 3ms/step - loss: 1.7950 - val_loss: 1.8088
# Epoch 214/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7952 - val_loss: 1.7980
# Epoch 215/300
# 336/336 [==============================] - 1s 3ms/step - loss: 1.7980 - val_loss: 1.7978
# Epoch 216/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7941 - val_loss: 1.8056
# Epoch 217/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7958 - val_loss: 1.8118
# Epoch 218/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7937 - val_loss: 1.8024
# Epoch 219/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7923 - val_loss: 1.8000
# Epoch 220/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7924 - val_loss: 1.7955
# Epoch 221/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7959 - val_loss: 1.8074
# Epoch 222/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7947 - val_loss: 1.7939
# Epoch 223/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7958 - val_loss: 1.8054
# Epoch 224/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7920 - val_loss: 1.8070
# Epoch 225/300
# 336/336 [==============================] - 1s 3ms/step - loss: 1.7924 - val_loss: 1.8049
# Epoch 226/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7913 - val_loss: 1.8017
# Epoch 227/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7947 - val_loss: 1.8045
# Epoch 228/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7952 - val_loss: 1.8044
# Epoch 229/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7928 - val_loss: 1.7998
# Epoch 230/300
# 336/336 [==============================] - 1s 3ms/step - loss: 1.7921 - val_loss: 1.7974
# Epoch 231/300
# 336/336 [==============================] - 1s 3ms/step - loss: 1.7935 - val_loss: 1.7984
# Epoch 232/300
# 336/336 [==============================] - 1s 3ms/step - loss: 1.7922 - val_loss: 1.8036
# Epoch 233/300
# 336/336 [==============================] - 1s 3ms/step - loss: 1.7958 - val_loss: 1.7981
# Epoch 234/300
# 336/336 [==============================] - 1s 3ms/step - loss: 1.7921 - val_loss: 1.7958
# Epoch 235/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7968 - val_loss: 1.8007
# Epoch 236/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7912 - val_loss: 1.8064
# Epoch 237/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7933 - val_loss: 1.7971
# Epoch 238/300
# 336/336 [==============================] - 1s 2ms/step - loss: 1.7971 - val_loss: 1.7998
# Epoch 239/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7958 - val_loss: 1.8058
# Epoch 240/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7917 - val_loss: 1.7991
# Epoch 241/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7954 - val_loss: 1.7985
# Epoch 242/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7909 - val_loss: 1.8015
# Epoch 243/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7933 - val_loss: 1.8031
# Epoch 244/300
# 336/336 [==============================] - 0s 943us/step - loss: 1.7934 - val_loss: 1.7985
# Epoch 245/300
# 336/336 [==============================] - 0s 966us/step - loss: 1.7923 - val_loss: 1.8026
# Epoch 246/300
# 336/336 [==============================] - 0s 979us/step - loss: 1.7962 - val_loss: 1.7967
# Epoch 247/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7937 - val_loss: 1.7980
# Epoch 248/300
# 336/336 [==============================] - 0s 943us/step - loss: 1.7942 - val_loss: 1.8044
# Epoch 249/300
# 336/336 [==============================] - 0s 939us/step - loss: 1.7900 - val_loss: 1.7977
# Epoch 250/300
# 336/336 [==============================] - 0s 943us/step - loss: 1.7928 - val_loss: 1.7991
# Epoch 251/300
# 336/336 [==============================] - 0s 973us/step - loss: 1.7923 - val_loss: 1.7986
# Epoch 252/300
# 336/336 [==============================] - 0s 979us/step - loss: 1.7951 - val_loss: 1.7931
# Epoch 253/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.
300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7940 - val_loss: 1.8082
# Epoch 296/300
# 336/336 [==============================] - 0s 1ms/step - loss: 1.7912 - val_loss: 1.7968
# Epoch 297/300
# 336/336 [==============================] - 0s 976us/step - loss: 1.7898 - val_loss: 1.8078
# Epoch 298/300
# 336/336 [==============================] - 0s 967us/step - loss: 1.7938 - val_loss: 1.8035
# Epoch 299/300
# 336/336 [==============================] - 0s 958us/step - loss: 1.7937 - val_loss: 1.7975
# Epoch 300/300
# 336/336 [==============================] - 0s 978us/step - loss: 1.7928 - val_loss: 1.7973

# %%
def latent_space_data(vae, data):
    encoder, decoder = vae
    z_mean, _, _ = encoder.predict(data)
    return z_mean
LS_GMSC_train = latent_space_data(models, X_data)
LS_GMSC_test = latent_space_data(models, X_test)

# %% [markdown]
# #### Metric function

# %%
def metric_score(y_test, y_pred):
    confMat=confusion_matrix(y_test, y_pred) 
    confMat
    TP = confMat[1,1]
    TN = confMat[0,0]
    FP = confMat[0,1]
    FN = confMat[1,0]
    TP,FP,TN,FN
    Eta = 1/2*((TP/np.sum(y_test==1))+(TN/np.sum(y_test==0)))
    TPR = TP/(TP+FN)
    TNR = TN/(TN+FP)
    Gmean = np.sqrt(TPR*TNR)
    return(TPR,TNR,Gmean,Eta)

# %% [markdown]
# ### MSPO

# %%
    #def SPOfn(latent_space_im,mino,majo,y_d):
       
    #Input - P and N
    # Output = Me(mean), 
    #V - Eigen matrix, 
    #D - Modified eigen spectrurm value, 
    #M -  the portion of reliable
    latent_space_im = LS_GMSC_train
    mino = 1
    majo = 0
    y_d = y_data
    
    nTarget = np.sum(y_d == majo)


    posy = y_d == mino
    negy = y_d != mino
    P = latent_space_im[np.where(posy == True)[0],:]
    N = latent_space_im[np.where(negy == True)[0],:]

    #print(len(P),len(N))

    poscnt = P.shape[0]
    NumToGen = nTarget - poscnt
    Me  = np.mean((P),axis = 0)
    PCov = np.cov(P.T)
    #print(NumToGen)
    [D,V] = np.linalg.eig(PCov)
    #d = [D[x,x] for x in range(D.shape[0])]
    d = D
    #d = d.astype(np.float32)
    n = P.shape[1] #Feature dimension
    idx = d.argsort()[::-1]   
    d = d[idx]
    V = V[:,idx]
      
    
    Ind = (d<= 5e-09)

    if np.sum(Ind) != 0:
        M = (list(Ind).index(True)+1)
    else:
        M = n
        
    #print(Ind,M)

    PN = np.concatenate((P,N),axis=0)
    TCov = np.cov(PN.T)
    dT    = np.dot(V.T,np.dot(TCov, V))
    dT = [dT[x,x] for x in range(dT.shape[0])]
    

    #Modify the Eigen spectrum according to a 1-Parameter Model
    dMod  = np.zeros((n,1))
    Alpha = d[0]* d[M-1]*(M-1) /(d[0] - d[M-1]) #d[0]* d[M-1]*(M-1) /(d[0] - d[M-1])
    Beta  = ((M)*d[M-1] - d[0])/(d[0] - d[M-1])
    
    for i in range(n):
        if i<M-1:

            dMod[i] = d[i]
        else:
            dMod[i] = Alpha/(i+1+Beta)
            if dMod[i] > dT[i]:
                dMod[i] = dT[i]

    R = 0.1
    d = dMod
   
    ########################################
    

    Rn = M
    Un = len(Me) - M
    Ptemp = P

    MuR = np.zeros((Rn,1)) #mlayer#
    SigmaR = np.identity((Rn)) #v_mat #

    MuU = np.zeros((Un,1))
    SigmaU = np.identity((Un))

    SampGen = np.zeros((int(NumToGen*R), len(Me)))
    SampSel = np.zeros((int(NumToGen), len(Me)))
    Prob    = np.zeros((int(NumToGen*R),1))

    cnt = 0
    DD = np.sqrt(d)
    MuR = MuR.reshape(MuR.shape[0],)
    MuU = MuU.reshape(MuU.shape[0],)
    #print(R*NumToGen)

    while cnt < int(R*NumToGen):
        
       
        aR =  np.random.multivariate_normal(MuR.T, SigmaR, 1)
        #print(aR)
        #scipy.stats.multivariate_normal(MuR.T, SigmaR, 1)
        tp = multivariate_normal.pdf(aR, MuR, SigmaR) #aR.pdf(1)
        #print(tp)

        if Un > 0:
            aU = np.random.multivariate_normal(MuU, SigmaU, 1)
            #scipy.stats.multivariate_normal(MuU, SigmaU, 1)
            a = np.multiply(np.concatenate((aR,aU),axis=1).T,DD)   #The vector in Eigen transformed domain;
        else:
            a = np.multiply(aR.T,DD)
            #print(a)

        x = np.dot(a.T,V.T)+ Me
        #print(x)
        #pdb.set_trace()
        PDist = np.sqrt(np.sum(np.square((x-P)),axis=1))
        NDist = np.sqrt(np.sum(np.square((x-N)),axis=1))

        [tmp,ind]  = [np.min(NDist),np.argmin(NDist)]

        if np.min(PDist) < tmp:
            PPDist = np.sqrt(np.sum(np.square((N[ind,:]-P)),axis=1))
            if tmp >= np.min(PPDist) and tmp <= np.max(PPDist):
                SampGen[cnt,:] = x
                Prob[cnt,0] = tp  
                cnt+=1
                Ptemp = np.concatenate((Ptemp,SampGen),axis =0)

    for i in range(NumToGen):
        [tmp,ind]  = [np.min(Prob),np.argmin(Prob)]
        Prob[ind] =  np.inf
        SampSel[i,:] = SampGen[ind,:]

    Ynew = SampSel #np.concatenate((SampSel,P),axis = 0)
    #Total = np.concatenate((Ynew,N),axis = 0)
    
    #return Ynew

# %%
print("No of samples generated:",cnt)
# Out:
# No of samples generated: 9096

# %%
Datanew = np.concatenate((SampSel,P),axis = 0)
Total = np.concatenate((Datanew,N),axis = 0)

# %%
label = np.zeros((Total.shape[0],))
label[0:Datanew.shape[0]] = 1
label[Datanew.shape[0]:Total.shape[0]] = 0

# %%
Total.shape
# Out:
# (195964, 3)

# %%
X_train = (Total)
y_train = (label)
X_test = (LS_GMSC_test)
y_test = (y_test)


mm_X = MinMaxScaler(feature_range=(-1.0,1.0))
X_trainscaled= mm_X.fit_transform(X_train) #mm_X.fit_transform(X_train)  #sc_X.fit_transform(X_train)
X_testscaled= mm_X.transform(X_test) #mm_X.transform(X_test)  #sc_X.transform(X_test)

clf = MLPClassifier(solver='adam',hidden_layer_sizes=(8,47,5),activation="relu",
                    random_state=1,max_iter = 5000,batch_size=200,learning_rate_init=0.31,
                    learning_rate ='constant',warm_start = True)
# 10,32,8,3 5,10,8,3,
clf.fit(X_trainscaled, y_train)

y_pred=clf.predict(X_testscaled)
#print(clf.score(X_testscaled, y_test))

print(metric_score(y_test, y_pred))
# Out:
# (0.6605718085106383, 0.5833015812535721, 0.6207355156874683, 0.6219366948821052)

# %%
print('Time taken :',time.time()-start_time)
# Out:
# Time taken : 3910.5265486240387
